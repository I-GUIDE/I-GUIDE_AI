# %% [markdown]
# # Notebook Templates.

# %%
# Metadata
Author = "Your Name"
Date = "YYYY-MM-DD"
Python_Version = "3.x"
Last_Run = "YYYY-MM-DD"
Purpose = "Demonstrate Jupyter best practices for reproducible research"

# %% [markdown]
# ## Imports and Directories

# %%
# Imports
import numpy as np


# Set seed
np.random.seed(42)

# Define relative paths
DATA_DIR = Path("data")
OUTPUT_DIR = Path("outputs")
DATA_DIR.mkdir(exist_ok=True)
OUTPUT_DIR.mkdir(exist_ok=True)

# %% [markdown]
# ## Dependency Management
#
# - Create a `requirements.txt` or `environment.yml` file for reproducibility.
# - Avoid installing packages directly in the notebook unless absolutely necessary.

# %% [markdown]
# ## Load or Create Data
#
# - Use **relative paths** to load data.
# - Save and reload example data to demonstrate reproducibility.
# - Keep datasets small or provide download instructions if large.

# %%
# Load Data

# %% [markdown]
# ## Analysis 1
#
# - Include a Markdown explanation for each code section.
# - Clearly explain what the analysis is doing and why.
# - Avoid hidden state; code should run from top to bottom.

# %%
# Analysis Code

# %% [markdown]
# ## Visualization 1
#
# - Label axes and titles clearly.
# - Keep plotting code **separate** from analysis code.
# - Use consistent figure sizing for readability.
# - Include visualizations in each section if possible.

# %%
# Visualization Code

# %% [markdown]
# ## Export Results 1
#
# - Save processed results in a reproducible format.
# - Use relative paths for saving outputs.
# - Keep outputs organized in a separate folder.

# %%
# Save Results

# %% [markdown]
# ## Analysis 2
#
# - Include a Markdown explanation for each code section.
# - Clearly explain what the analysis is doing and why.
# - Avoid hidden state; code should run from top to bottom.

# %%
# Analysis Code

# %% [markdown]
# ## Visualization 2
#
# - Label axes and titles clearly.
# - Keep plotting code **separate** from analysis code.
# - Use consistent figure sizing for readability.
# - Include visualizations in each section if possible.

# %%
# Visualization Code

# %% [markdown]
# ## Export Results 2
#
# - Save processed results in a reproducible format.
# - Use relative paths for saving outputs.
# - Keep outputs organized in a separate folder.

# %%
# Save Results
