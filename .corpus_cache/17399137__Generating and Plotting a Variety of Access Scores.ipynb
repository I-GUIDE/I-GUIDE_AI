# %% [markdown]
# # Using the Pysal Access Package on the I-GUIDE Platform
#
# *This notebook was taken from the `pysal/access` repository with minimal changes: https://github.com/pysal/access/blob/main/notebooks/Generating%20and%20Plotting%20a%20Variety%20of%20Access%20Scores.ipynb*
#
# You can also read the documentation here: https://pysal.org/access/api.html

# %%
from access import Access, weights, Datasets

import logging
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Example Data Sets
# The `Datasets` class provides a number of datasets that are used in this and other examples showing how to use the `Access` package. You can see the available datasets by running the following command.

# %%
Datasets.available_datasets()  # will update the output of this to be more descriptive rather than just the file names
# Out:
# chi_times: Cost matrix with travel times from each Chicago Census Tract to all others.
#
# chi_doc: Doctor and dentist counts for each Chicago Census Tract.
#
# chi_pop: Population counts for each Chicago Census Tract.
#
# chi_doc_geom: Doctor and dentist counts for each Chicago Census Tract along with geometric representations for Census Tracts.
#
# chi_pop_geom: Population counts for each Chicago Census Tract along with geometric representations for Census Tracts.
#
# chi_euclidean: Euclidean distance cost matrix with distances from each demand Chicago Census Tract to all others.
#
# chi_euclidean_neighbors: Euclidean distance cost matrix with distances from each supply Census Tract to all others.
#
# cook_county_hospitals: Contains data for each hospital location in Cook County including X Y coordinates.
#
# cook_county_hospitals_geom: Contains data for each hospital location in Cook County including X Y coordinates, and geometric points for each hospital.
#
# cook_county_tracts: Geometric representation of each Census Tract in Cook County.

# %% [markdown]
# For this exercise, we'll need three datasets to instantiate an instance of `Access`:
# - demand dataset (chi_pop_geom)
# - supply dataset (chi_doc_geom)
# - cost matrix (chi_times)
#
# **NOTE:** In this example, we'll be using the `_geom` variants so that we can calculate euclidean distances between points and use euclidean distance as a cost metric. If you have already have a cost matrix, you won't need the geometric data.

# %% [markdown]
# ### Load Supply and Demand Data
# Each of the datasets shown below show population and doctor/dentist counts, respectively, at the Census Tract level for all Census Tracts in and within and 50km of Chicago's boundaries.

# %%
chi_pop = Datasets.load_data("chi_pop_geom")
chi_doc = Datasets.load_data("chi_doc_geom")

# %%
chi_pop.head()
# Out:
#          geoid   pop                       geometry
# 0  17031010100  4854  POINT (354916.992 594670.505)
# 1  17031010201  6450  POINT (354105.876 594088.600)
# 2  17031010202  2818  POINT (354650.684 594093.822)
# 3  17031010300  6236  POINT (355209.361 594086.149)
# 4  17031010400  5042  POINT (355809.748 592808.043)

# %%
chi_pop.explore(column="pop")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ffa81c69cbabdbbd9db4d0d17ccd93c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ffa81c69cbabdbbd9db4d0d17ccd93c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ffa81c69cbabdbbd9db4d0d17ccd93c = L.map(
#                 &quot;map_8ffa81c69cbabdbbd9db4d0d17ccd93c&quot;,
#                 {
#                     center: [41.8969729187104, -87.98130530851532],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8ffa81c69cbabdbbd9db4d0d17ccd93c);
#
#
#
#
#
#             var tile_layer_4320798feb4ae10c8dca9cc4561efc26 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ffa81c69cbabdbbd9db4d0d17ccd93c);
#
#
#             map_8ffa81c69cbabdbbd9db4d0d17ccd93c.fitBounds(
#                 [[41.33872344633025, -88.43194168342453], [42.455222391090544, -87.5306689336061]],
#                 {}
#             );
#
#
#         function geo_json_1d76b4cd4a57e6aadc5881177e25ae57_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;64&quot;: case &quot;81&quot;: case &quot;151&quot;: case &quot;152&quot;: case &quot;179&quot;: case &quot;353&quot;: case &quot;535&quot;: case &quot;581&quot;: case &quot;726&quot;: case &quot;727&quot;: case &quot;741&quot;: case &quot;895&quot;: case &quot;918&quot;: case &quot;920&quot;: case &quot;977&quot;: case &quot;981&quot;: case &quot;1106&quot;: case &quot;1164&quot;: case &quot;1327&quot;: case &quot;1337&quot;: case &quot;1454&quot;: case &quot;1574&quot;: case &quot;1654&quot;: case &quot;1705&quot;: case &quot;1741&quot;: case &quot;1782&quot;: case &quot;1859&quot;:
#                     return {&quot;color&quot;: &quot;#3a548c&quot;, &quot;fillColor&quot;: &quot;#3a548c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;32&quot;: case &quot;330&quot;: case &quot;455&quot;: case &quot;565&quot;: case &quot;831&quot;: case &quot;851&quot;: case &quot;914&quot;: case &quot;975&quot;: case &quot;1063&quot;: case &quot;1104&quot;: case &quot;1135&quot;: case &quot;1172&quot;: case &quot;1321&quot;: case &quot;1585&quot;: case &quot;1662&quot;: case &quot;1755&quot;:
#                     return {&quot;color&quot;: &quot;#2f6b8e&quot;, &quot;fillColor&quot;: &quot;#2f6b8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;38&quot;: case &quot;154&quot;: case &quot;172&quot;: case &quot;186&quot;: case &quot;261&quot;: case &quot;299&quot;: case &quot;517&quot;: case &quot;553&quot;: case &quot;863&quot;: case &quot;932&quot;: case &quot;982&quot;: case &quot;1229&quot;: case &quot;1264&quot;: case &quot;1308&quot;: case &quot;1312&quot;: case &quot;1365&quot;: case &quot;1516&quot;: case &quot;1837&quot;: case &quot;1928&quot;:
#                     return {&quot;color&quot;: &quot;#463480&quot;, &quot;fillColor&quot;: &quot;#463480&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;16&quot;: case &quot;54&quot;: case &quot;137&quot;: case &quot;148&quot;: case &quot;175&quot;: case &quot;502&quot;: case &quot;683&quot;: case &quot;730&quot;: case &quot;923&quot;: case &quot;962&quot;: case &quot;1054&quot;: case &quot;1354&quot;: case &quot;1361&quot;: case &quot;1474&quot;: case &quot;1497&quot;: case &quot;1593&quot;: case &quot;1838&quot;: case &quot;1890&quot;:
#                     return {&quot;color&quot;: &quot;#31688e&quot;, &quot;fillColor&quot;: &quot;#31688e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;165&quot;: case &quot;232&quot;: case &quot;251&quot;: case &quot;369&quot;: case &quot;458&quot;: case &quot;536&quot;: case &quot;642&quot;: case &quot;721&quot;: case &quot;846&quot;: case &quot;908&quot;: case &quot;1034&quot;: case &quot;1071&quot;: case &quot;1199&quot;: case &quot;1213&quot;: case &quot;1393&quot;: case &quot;1394&quot;: case &quot;1401&quot;: case &q

# %%
chi_doc.head()
# Out:
#          geoid  doc  dentist                       geometry
# 0  17031010100    1        1  POINT (354916.992 594670.505)
# 1  17031010201    0        1  POINT (354105.876 594088.600)
# 2  17031010202    4        1  POINT (354650.684 594093.822)
# 3  17031010300    4        1  POINT (355209.361 594086.149)
# 4  17031010400    0        2  POINT (355809.748 592808.043)

# %%
chi_doc.explore(column="doc")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95849656d21754de1137950f641de60a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95849656d21754de1137950f641de60a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95849656d21754de1137950f641de60a = L.map(
#                 &quot;map_95849656d21754de1137950f641de60a&quot;,
#                 {
#                     center: [41.8969729187104, -87.98130530851532],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_95849656d21754de1137950f641de60a);
#
#
#
#
#
#             var tile_layer_9bd24afe299dfcf92466ac50260bb8e0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_95849656d21754de1137950f641de60a);
#
#
#             map_95849656d21754de1137950f641de60a.fitBounds(
#                 [[41.33872344633025, -88.43194168342453], [42.455222391090544, -87.5306689336061]],
#                 {}
#             );
#
#
#         function geo_json_50d2d7107f50f3c253748c70891d5a73_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;9&quot;: case &quot;11&quot;: case &quot;19&quot;: case &quot;29&quot;: case &quot;34&quot;: case &quot;36&quot;: case &quot;39&quot;: case &quot;49&quot;: case &quot;51&quot;: case &quot;57&quot;: case &quot;60&quot;: case &quot;69&quot;: case &quot;75&quot;: case &quot;78&quot;: case &quot;99&quot;: case &quot;106&quot;: case &quot;109&quot;: case &quot;110&quot;: case &quot;114&quot;: case &quot;124&quot;: case &quot;125&quot;: case &quot;126&quot;: case &quot;134&quot;: case &quot;157&quot;: case &quot;166&quot;: case &quot;167&quot;: case &quot;170&quot;: case &quot;173&quot;: case &quot;175&quot;: case &quot;177&quot;: case &quot;186&quot;: case &quot;192&quot;: case &quot;193&quot;: case &quot;199&quot;: case &quot;201&quot;: case &quot;211&quot;: case &quot;223&quot;: case &quot;232&quot;: case &quot;235&quot;: case &quot;237&quot;: case &quot;240&quot;: case &quot;248&quot;: case &quot;272&quot;: case &quot;275&quot;: case &quot;277&quot;: case &quot;298&quot;: case &quot;304&quot;: case &quot;310&quot;: case &quot;315&quot;: case &quot;316&quot;: case &quot;331&quot;: case &quot;341&quot;: case &quot;348&quot;: case &quot;349&quot;: case &quot;350&quot;: case &quot;355&quot;: case &quot;367&quot;: case &quot;379&quot;: case &quot;390&quot;: case &quot;397&quot;: case &quot;399&quot;: case &quot;402&quot;: case &quot;403&quot;: case &quot;405&quot;: case &quot;410&quot;: case &quot;418&quot;: case &quot;431&quot;: case &quot;438&quot;: case &quot;439&quot;: case &quot;447&quot;: case &quot;450&quot;: case &quot;456&quot;: case &quot;459&quot;: case &quot;461&quot;: case &quot;465&quot;: case &quot;473&quot;: case &quot;477&quot;: case &quot;480&quot;: case &quot;489&quot;: case &quot;490&quot;: case &quot;494&quot;: case &quot;504&quot;: case &quot;515&quot;: case &quot;522&quot;: case &quot;527&quot;: case &quot;531&quot;: case &quot;535&quot;: case &quot;536&quot;: case &quot;542&quot;: case &quot;548&quot;: case &quot;549&quot;: case &quot;559&quot;: case &quot;564&quot;: case &quot;565&quot;: case &quot;578&quot;: case &quot;601&quot;: case &quot;607&quot;: case &quot;608&quot;: case &quot;619&quot;: case &quot;623&quot;: case &quot;631&quot;: case &quot;632&quot;: case &quot;633&quot;: case &quot;641&quot;: case &quot;644&quot;: case &quot;648&quot;: case &quot;650&quot;: case &quot;651&quot;: case &quot;652&quot;: case &quot;657&quot;: case &quot;660&quot;: case &quot;690&quot;: case &quot;692&quot;: case &quot;700&quot;: case &quot;728&quot;: case &quot;731&quot;: case &quot;733&quot;: case &quot;734&quot;: case &quot;736&quot;: case &quot;749&quot;: case &quot;755&quot;: case &quot;756&quot;: case &quot;757&quot;: case &quot;768&quot;: case &quot;769&quot;: case &quot;771&quot;: case &quot;774&quot;: case &quot;777&quot;: case &quot;778&quot;: case &quot;779&quot;: case &quot;783&quot;: case &quot;784&quot;: case &quot;788&quot;: case &quot;795&quot;: case &quot;798&quot;: case &quot;814&quot;: case &quot;81

# %%
chi_doc.explore(column="dentist")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9078dd3d7ebe8c812bc8e69b8c8878c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9078dd3d7ebe8c812bc8e69b8c8878c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9078dd3d7ebe8c812bc8e69b8c8878c4 = L.map(
#                 &quot;map_9078dd3d7ebe8c812bc8e69b8c8878c4&quot;,
#                 {
#                     center: [41.8969729187104, -87.98130530851532],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9078dd3d7ebe8c812bc8e69b8c8878c4);
#
#
#
#
#
#             var tile_layer_898e2b9d6db0aafd7660c88fd0bdf936 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9078dd3d7ebe8c812bc8e69b8c8878c4);
#
#
#             map_9078dd3d7ebe8c812bc8e69b8c8878c4.fitBounds(
#                 [[41.33872344633025, -88.43194168342453], [42.455222391090544, -87.5306689336061]],
#                 {}
#             );
#
#
#         function geo_json_e7b14e95d6930819343ece45fe263365_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;9&quot;: case &quot;12&quot;: case &quot;16&quot;: case &quot;23&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;36&quot;: case &quot;41&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;53&quot;: case &quot;56&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;88&quot;: case &quot;101&quot;: case &quot;112&quot;: case &quot;114&quot;: case &quot;115&quot;: case &quot;130&quot;: case &quot;133&quot;: case &quot;143&quot;: case &quot;145&quot;: case &quot;148&quot;: case &quot;167&quot;: case &quot;171&quot;: case &quot;173&quot;: case &quot;187&quot;: case &quot;192&quot;: case &quot;195&quot;: case &quot;196&quot;: case &quot;198&quot;: case &quot;205&quot;: case &quot;209&quot;: case &quot;223&quot;: case &quot;229&quot;: case &quot;230&quot;: case &quot;233&quot;: case &quot;235&quot;: case &quot;237&quot;: case &quot;238&quot;: case &quot;239&quot;: case &quot;246&quot;: case &quot;247&quot;: case &quot;260&quot;: case &quot;263&quot;: case &quot;264&quot;: case &quot;279&quot;: case &quot;280&quot;: case &quot;287&quot;: case &quot;289&quot;: case &quot;321&quot;: case &quot;324&quot;: case &quot;351&quot;: case &quot;354&quot;: case &quot;355&quot;: case &quot;357&quot;: case &quot;374&quot;: case &quot;384&quot;: case &quot;391&quot;: case &quot;392&quot;: case &quot;404&quot;: case &quot;407&quot;: case &quot;409&quot;: case &quot;412&quot;: case &quot;417&quot;: case &quot;422&quot;: case &quot;429&quot;: case &quot;436&quot;: case &quot;439&quot;: case &quot;445&quot;: case &quot;447&quot;: case &quot;448&quot;: case &quot;450&quot;: case &quot;455&quot;: case &quot;456&quot;: case &quot;467&quot;: case &quot;477&quot;: case &quot;479&quot;: case &quot;488&quot;: case &quot;489&quot;: case &quot;490&quot;: case &quot;494&quot;: case &quot;496&quot;: case &quot;526&quot;: case &quot;529&quot;: case &quot;530&quot;: case &quot;544&quot;: case &quot;553&quot;: case &quot;563&quot;: case &quot;571&quot;: case &quot;573&quot;: case &quot;578&quot;: case &quot;580&quot;: case &quot;585&quot;: case &quot;588&quot;: case &quot;590&quot;: case &quot;593&quot;: case &quot;594&quot;: case &quot;595&quot;: case &quot;610&quot;: case &quot;618&quot;: case &quot;623&quot;: case &quot;626&quot;: case &quot;630&quot;: case &quot;632&quot;: case &quot;635&quot;: case &quot;650&quot;: case &quot;654&quot;: case &quot;662&quot;: case &quot;664&quot;: case &quot;669&quot;: case &quot;674&quot;: case &quot;682&quot;: case &quot;687&quot;: case &quot;689&quot;: case &quot;697&quot;: case &quot;711&quot;: case &quot;720&quot;: case &quot;721&quot;: case &quot;722&quot;: case &quot;735&quot;: case &quot;751&quot;: case &quot;772&quot;: case &quot;773&quot;: case &

# %% [markdown]
# ### Loading Network Distance Data
#
# The chi_times contains geoid fields for the origin and destination tracts and a cost field (number of minutes it takes to travel from origin to destination). See the [main site's cost matrix section](https://access.readthedocs.io/en/latest/resources.html) for hints on downloading lots of travel times like this.

# %%
chi_times = Datasets.load_data("chi_times")

# %%
chi_times.head()
# Out:
#         origin         dest   cost
# 0  17093890101  17031010100  91.20
# 1  17093890101  17031010201  92.82
# 2  17093890101  17031010202  92.95
# 3  17093890101  17031010300  89.40
# 4  17093890101  17031010400  84.97

# %% [markdown]
# ## Create the `access` Object
#
# Since we have geometries here, it could be as simple as this:

# %%
A = Access(
    demand_df=chi_pop,
    demand_index="geoid",
    demand_value="pop",
    supply_df=chi_doc,
    supply_index="geoid",
    supply_value=["doc", "dentist"],
    cost_df=chi_times,
    cost_origin="origin",
    cost_dest="dest",
    cost_name="cost",
    neighbor_cost_df=chi_times,
    neighbor_cost_origin="origin",
    neighbor_cost_dest="dest",
    neighbor_cost_name="cost",
)

# %% [markdown]
# ### Add an Additional Distance Measure - Euclidean Distance
#
# Though we've already loaded a network distance matrix, we can still add a Euclidean distance matrix. This requires geopandas to be installed, and you should already have projected the data. In case you have not, below we show how to see your current projection, and how to change it to the correct one (if you don't know what projection to use, you can reference the [spatial reference](https://spatialreference.org/) website).

# %%
print(A.demand_df.crs)
print(A.supply_df.crs)
# Out:
# epsg:2790
# epsg:2790

# %%
A.demand_df = A.demand_df.to_crs(epsg=3528)
A.supply_df = A.supply_df.to_crs(epsg=3528)

# %% [markdown]
# Now we'll calculate the Euclidean distance matrix. Note that this is a very costly operation, but you only have to do it once.  `threshold` is the maximum distance (km) that we will consider. Calculating distances between centroids takes a while but is still faster than computing distances to polygons (crazy expensive, though we've been moderately careful to make it faster).

# %%
A.create_euclidean_distance(threshold=250000, centroid_o=True, centroid_d=True)

# %% [markdown]
# Calling `A.cost_df` will now show the 'eulidean' column in the cost dataframe.

# %%
A.cost_df
# Out:
#               origin         dest   cost     euclidean
# 0        17093890101  17031010100  91.20  63630.788476
# 1        17093890101  17031010201  92.82  62632.675522
# 2        17093890101  17031010202  92.95  63073.735631
# 3        17093890101  17031010300  89.40  63520.029749
# 4        17093890101  17031010400  84.97  63268.514352
# ...              ...          ...    ...           ...
# 4284625  17197980100  17111870809    NaN  80097.128392
# 4284626  17197980100  17111871310    NaN  67358.028756
# 4284627  17197980100  17197880308    NaN  11161.067033
# 4284628  17197980100  17197881007    NaN  14547.843032
# 4284629  17197980100  17197883809    NaN  42025.297449
#
# [4284630 rows x 4 columns]

# %% [markdown]
# ### Create Some Weight Functions
#
# Of course, you don't _have_ to do this, but it's fun to play with different versions of spatial access, esp. E2SFCA. You can create the weighting functionsfrom stepwise weight dictionaries.

# %%
fn30 = weights.step_fn({10: 1, 20: 0.68, 30: 0.22})
fn60 = weights.step_fn({20: 1, 40: 0.68, 60: 0.22})

# %% [markdown]
# Or, you can use gaussian weights.  Here, we're using a value of 20 (minutes), such that we'll be at the 3σ level at 60 minutes.
#
# This could also be done through scipy.stats.norm().pdf, but that turns out to be unacceptably slow.

# %%
gaussian = weights.gaussian(20)

# %% [markdown]
# Lastly, you could use a conventional gravity model, which is just weighted catchment with gravity weighting.

# %%
gravity = weights.gravity(scale=60, alpha=-1)

# %% [markdown]
# ## Ready to roll...
#
# Now just call the access functions. Each of these will return the corresponding series, but they are also stored in `A.access_df`.  Check out the documentation for the possible arguments. Note that if you call the same function repeatedly, with different arguments, you may want to change the name, to avoid overwriting. By default, `access` will calculate access metrics for each of the supply columns unless you specify a particular subset.

# %%
A.weighted_catchment(name="gravity", weight_fn=gravity)
A.fca_ratio(name="fca", max_cost=15)
A.fca_ratio(name="fca", max_cost=30)  # Note - the warning -- good!
A.fca_ratio(name="fca60", max_cost=60)
A.fca_ratio(name="fca90", max_cost=90)
A.two_stage_fca(name="2sfca", max_cost=60)
A.enhanced_two_stage_fca(name="2sfca30", weight_fn=fn30)
A.enhanced_two_stage_fca(name="2sfca60", weight_fn=fn60)
A.enhanced_two_stage_fca(name="g2sfca", weight_fn=gaussian)
A.three_stage_fca(name="3sfca")

A.raam(name="raam", tau=60)
A.raam(name="raam30", tau=30);
# Out:
# access INFO     :: Using default cost, cost, for gravity.
# access INFO     :: Using default cost, cost, for fca.
# access INFO     :: Using default neighbor cost, cost, for fca.
# access INFO     :: Using default cost, cost, for fca.
# access INFO     :: Using default neighbor cost, cost, for fca.
# access INFO     :: Overwriting fca_doc.
# access INFO     :: Overwriting fca_dentist.
# access INFO     :: Using default cost, cost, for fca60.
# access INFO     :: Using default neighbor cost, cost, for fca60.
# access INFO     :: Using default cost, cost, for fca90.
# access INFO     :: Using default neighbor cost, cost, for fca90.
# access INFO     :: Using default cost, cost, for 2sfca.
# access INFO     :: Using default cost, cost, for 2sfca30.
# access INFO     :: Using default cost, cost, for 2sfca60.
# access INFO     :: Using default cost, cost, for g2sfca.
# access INFO     :: Using default cost, cost, for 3sfca.
# access INFO     :: Using default cost, cost, for raam.
# access INFO     :: Using default cost, cost, for raam30.

# %%
A.access_df.sort_values(by="raam_doc").dropna().head()
# Out:
#               pop   gravity_doc  gravity_dentist   fca_doc  fca_dentist
# geoid
# 17031808800  3955  48874.111283      7990.336879  0.001049     0.000878  \
# 17031809300  4816  14613.314584      6731.779891  0.001082     0.000821
# 17031806801  4225  17700.521096     10206.437126  0.001036     0.000936
# 17031809100  3387  10512.460373      6840.560712  0.001109     0.000886
# 17031808702  5504  23763.514763      8244.668327  0.001106     0.000779
#
#              fca60_doc  fca60_dentist  fca90_doc  fca90_dentist  2sfca_doc
# geoid
# 17031808800   0.001100       0.000667   0.000912       0.000620   0.000760  \
# 17031809300   0.001174       0.000694   0.000925       0.000623   0.000690
# 17031806801   0.000988       0.000650   0.000901       0.000617   0.000930
# 17031809100   0.001059       0.000664   0.000906       0.000617   0.000845
# 17031808702   0.001179       0.000691   0.000928       0.000624   0.000650
#
#              ...  2sfca60_doc  2sfca60_dentist  g2sfca_doc  g2sfca_dentist
# geoid        ...
# 17031808800  ...     0.000650         0.000431    0.000700        0.000433  \
# 17031809300  ...     0.000635         0.000401    0.000683        0.000415
# 17031806801  ...     0.001029         0.000678    0.001045        0.000704
# 17031809100  ...     0.000805         0.000515    0.000829        0.000528
# 17031808702  ...     0.000626         0.000387    0.000645        0.000383
#
#              3sfca_doc  3sfca_dentist  raam_doc  raam_dentist  raam30_doc
# geoid
# 17031808800   0.001666       0.000963  0.610053      0.842621    0.518374  \
# 17031809300   0.001695       0.000965  0.654022      0.897259    0.605593
# 17031806801   0.001378       0.001067  0.676216      0.751016    0.588885
# 17031809100   0.001654       0.000950  0.701590      0.893923    0.690675
# 17031808702   0.001687       0.000912  0.703447      0.932076    0.686627
#
#              raam30_dentist
# geoid
# 17031808800        0.869783
# 17031809300        0.961986
# 17031806801        0.615765
# 17031809100        0.924893
# 17031808702        0.956822
#
# [5 rows x 23 columns]

# %% [markdown]
# These were all with network travel time, in minutes.  We could also run the calculation with Euclidean distance.  Note that the parameters for the access fucntion will be dramatically different in meters instead of minutes!  Here, RAAM's tau parameter shifts from 60 minutes to 100 km (1e5 meters).

# %%
raam = A.raam(name="raam_euclidean", tau=1e5, cost="euclidean")

raam.head()
# Out:
#              raam_euclidean_doc  raam_euclidean_dentist
# geoid
# 17031010100            0.837117                0.881353
# 17031010201            0.836282                0.899506
# 17031010202            0.842233                0.878215
# 17031010300            0.859648                0.891032
# 17031010400            0.893507                0.883204

# %% [markdown]
# Gosh -- that's lots of access measures!  Let's simplify our life, with just one:

# %%
A.score(name="raam_combo", col_dict={"raam_doc": 0.8, "raam_dentist": 0.2})
# Out:
# geoid
# 17031010100    0.760373
# 17031010201    0.751101
# 17031010202    0.782341
# 17031010300    0.825140
# 17031010400    0.913720
#                  ...
# 17197883903    1.485736
# 17197883904    1.392151
# 17197884101    1.402404
# 17197884103    1.388448
# 17197980100    1.381479
# Name: raam_combo, Length: 1930, dtype: float64

# %% [markdown]
# If there were only one cost function available, these logs wouldn't print.
#
# If you found all the logs annoying instead of useful, then turn them off:

# %%
A.log.setLevel(logging.WARNING)

# %% [markdown]
# ## Results time!
#
# Let's get the correlations among measures, and plot a few of them...

# %%
A.norm_access_df.columns
# Out:
# Index(['2sfca30_dentist', '2sfca30_doc', '2sfca60_dentist', '2sfca60_doc',
#        '2sfca_dentist', '2sfca_doc', '3sfca_dentist', '3sfca_doc',
#        'fca60_dentist', 'fca60_doc', 'fca90_dentist', 'fca90_doc',
#        'fca_dentist', 'fca_doc', 'g2sfca_dentist', 'g2sfca_doc',
#        'gravity_dentist', 'gravity_doc', 'raam30_dentist', 'raam30_doc',
#        'raam_combo', 'raam_dentist', 'raam_doc', 'raam_euclidean_dentist',
#        'raam_euclidean_doc'],
#       dtype='object')

# %%
A.norm_access_df.corr().raam_doc.abs().sort_values(ascending=False)
# Out:
# raam_doc                  1.000000
# raam_combo                0.983396
# raam30_doc                0.951257
# raam_euclidean_doc        0.871828
# 3sfca_doc                 0.858268
# fca_doc                   0.769326
# 2sfca30_doc               0.706941
# gravity_doc               0.688615
# g2sfca_doc                0.684157
# gravity_dentist           0.658659
# 2sfca60_doc               0.653054
# raam30_dentist            0.609425
# g2sfca_dentist            0.591621
# 2sfca60_dentist           0.589258
# raam_dentist              0.583213
# 2sfca_doc                 0.571955
# fca_dentist               0.563269
# 2sfca_dentist             0.546611
# 2sfca30_dentist           0.512455
# 3sfca_dentist             0.486922
# fca90_doc                 0.470519
# raam_euclidean_dentist    0.377358
# fca90_dentist             0.372606
# fca60_doc                 0.316764
# fca60_dentist             0.096010
# Name: raam_doc, dtype: float64

# %%
A.norm_access_df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_76642_row0_col0, #T_76642_row1_col1, #T_76642_row2_col2, #T_76642_row3_col3, #T_76642_row4_col4, #T_76642_row5_col5, #T_76642_row6_col6, #T_76642_row7_col7, #T_76642_row8_col8, #T_76642_row9_col9, #T_76642_row10_col10, #T_76642_row11_col11, #T_76642_row12_col12, #T_76642_row13_col13, #T_76642_row14_col14, #T_76642_row15_col15, #T_76642_row16_col16, #T_76642_row17_col17, #T_76642_row18_col18, #T_76642_row19_col19, #T_76642_row20_col20, #T_76642_row21_col21, #T_76642_row22_col22, #T_76642_row23_col23, #T_76642_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_76642_row0_col1, #T_76642_row1_col0, #T_76642_row1_col3, #T_76642_row3_col17, #T_76642_row7_col1, #T_76642_row16_col14, #T_76642_row17_col3, #T_76642_row18_col23 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_76642_row0_col2, #T_76642_row0_col6, #T_76642_row4_col16, #T_76642_row7_col13 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_76642_row0_col3, #T_76642_row16_col0, #T_76642_row17_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_76642_row0_col4, #T_76642_row0_col16, #T_76642_row4_col0, #T_76642_row7_col17, #T_76642_row21_col22 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_76642_row0_col5, #T_76642_row5_col0, #T_76642_row13_col5, #T_76642_row21_col24 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_76642_row0_col7, #T_76642_row0_col12, #T_76642_row4_col17, #T_76642_row7_col15, #T_76642_row16_col7, #T_76642_row17_col13, #T_76642_row22_col21 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_76642_row0_col8, #T_76642_row1_col9, #T_76642_row6_col11, #T_76642_row23_col13 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_76642_row0_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_76642_row0_col10, #T_76642_row2_col21, #T_76642_row12_col10, #T_76642_row16_col18 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_76642_row0_col11, #T_76642_row10_col13, #T_76642_row21_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_76642_row0_col13, #T_76642_row11_col18 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_76642_row0_col14, #T_76642_row24_col19 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_76642_row0_col15, #T_76642_row2_col17, #T_76642_row15_col0, #T_76642_row15_col13, #T_76642_row18_col19 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_76642_row0_col17, #T_76642_row19_col11, #T_76642_row22_col11 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_76642_row0_col18, #T_76642_row10_col3, #T_76642_row13_col19, #T_76642_row18_col2, #T_76642_row19_col4, #T_76642_row20_col4, #T_76642_row24_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_76642_row0_col19, #T_76642_row4_col20, #T_76642_row12_col22, #T_76642_row21_col9 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_76642_row0_col20, #T_76642_row2_col22, #T_76642_row10_col15, #T_76642_row17_col8, #T_76642_row18_col4, #T_76642_row20_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_76642_row0_col21, #T_76642_row5_col24, #T_76642_row11_col17, #T_76642_row12_col20, #T_76642_row14_col11, #T_76642_row16_col22, #T_76642_row21_col2, #T_76642_row23_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_76642_row0_col22, #T_76642_row19_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_76642_row0_col23, #T_76642_row14_col20, #T_76642_row17_col11, #T_76642_row20_col8 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_76642_row0_col24, #T_76642_row7_col18, #T_76642_row24_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_76642_row1_col2, #T_76642_row16_col4, #T_76642_row21_col20 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_76642_row1_col4, #T_76642_row1_col5, #T_76642_row5_col1, #T_76642_row12_col0, #T_76642_row24_col18 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_76642_row1_col6, #T_76642_row10_col22, #T_76642_row24_col23 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_76642_row1_col7, #T_76642_row2_col16, #T_76642_row3_col1, #T_76642_row23_col18 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_76642_row1_col8, #T_76642_row5_col18, #T_76642_row8_col23, #T_76642_row16_col21 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_76642_row1_col10, #T_76642_row18_col3, #T_76642_row18_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_76642_row1_col11, #T_76642_row6_col24, #T_76642_row18_col1, #T_76642_row18_col9, #T_76642_row23_col9 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_76642_row1_col12, #T_76642_row3_col12, #T_76642_row13_col0, #T_76642_row16_col12 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_76642_row1_col13, #T_76642_row3_col0, #T_76642_row18_col22 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_76642_row1_col14 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_76642_row1_col15, #T_76642_row4_col3 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_76642_row1_col16, #T_76642_row2_col0, #T_76642_row5_col16, #T_76642_row13_col7, #T_76642_row20_col21 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_76642_row1_col17, #T_76642_row2_col1, #T_76642_row16_col1, #T_76642_row18_col20 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_76642_row1_col18, #T_76642_row2_col8, #T_76642_row7_col10, #T_76642_row10_col1, #T_76642_row18_col17, #T_76642_row21_col13 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_76642_row1_col19, #T_76642_row10_col2, #T_76642_row11_col9 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_76642_row1_col20, #T_76642_row2_col24, #T_76642_row14_col24, #T_76642_row15_col22, #T_76642_row17_col22, #T_76642_row19_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_76642_row1_col21, #T_76642_row10_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_76642_row1_col22, #T_76642_row11_col15, #T_76642_row19_col9 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_76642_row1_col23, #T_76642_row7_col8, #T_76642_row8_col21, #T_76642_row13_col23, #T_76642_row17_col18 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_76642_row1_col24, #T_76642_row2_col11, #T_76642_row3_col24, #T_76642_row10_col5, #T_76642_row11_col16 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_76642_row2_col3, #T_76642_row2_col4, #T_76642_row3_col2, #T_76642_row4_col2, #T_76642_row19_col20, #T_76642_row19_col22, #T_76642_row20_col19, #T_76642_row22_col19 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_76642_row2_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_76642_row2_col6, #T_76642_row6_col14, #T_76642_row22_col23 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_76642_row2_col7, #T_76642_row4_col13, #T_76642_row13_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_76642_row2_col9, #T_76642_row8_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_76642_row2_col10, #T_76642_row20_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_76642_row2_col12 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_76642_row2_col13, #T_76642_row18_col24 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_76642_row2_col14, #T_76642_row3_col15, #T_76642_row14_col2, #T_76642_row15_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_76642_row2_col15, #T_76642_row3_col14, #T_76642_row5_col3, #T_76642_row14_col3, #T_76642_row15_col14 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_76642_row2_col18, #T_76642_row22_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_76642_row2_col19, #T_76642_row14_col22, #T_76642_row18_col7, #T_76642_row22_col12 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_76642_row2_col20, #T_76642_row5_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_76642_row2_col23 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_76642_row3_col4, #T_76642_row15_col1, #T_76642_row15_col2 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_76642_row3_col5, #T_76642_row5_col2, #T_76642_row14_col15 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_76642_row3_col6, #T_76642_row6_col4 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_76642_row3_

# %%
il_map = chi_doc.set_index("geoid")[["geometry"]].join(A.norm_access_df, how="inner")


def plot(v, ax=None, leg=True):

    swap_colors = "raam" in v

    il_map.plot(
        v,
        legend=leg,
        figsize=(5, 5),
        cmap="viridis_r" if swap_colors else "viridis",
        markersize=5,
        alpha=0.8,
        ax=ax,
        vmin=il_map[v].quantile(0.05),
        vmax=il_map[v].quantile(0.95),
    ).set_axis_off()

# %% [markdown]
# Plotting RAAM for spatial access to doctors from Chicago tracts:

# %%
plot("raam_doc")

# %% [markdown]
# Plotting 3-Stage Floating Catchment Areas for for spatial access to dentists from Chicago tracts:

# %%
plot("3sfca_dentist")

# %% [markdown]
# Fascinating!  Is it true that the dentist shortage on Chicago's South Side is more acute than for doctors?  This would not be a total shock, since Medicare boosts demand for healthcare but not dental care in poor areas -- and since the University of Chicago Hospital is bigish.  Let's do the apples to apples comparison, with RAAM.

# %% [markdown]
# From left to right, maps of RAAM for doctors, dentists and both:

# %%
fig, ax = plt.subplots(1, 3, subplot_kw={"aspect": "equal"})
for axi in ax:
    axi.set_axis_off()

plot("raam_doc", ax=ax[0], leg=False)
plot("raam_dentist", ax=ax[1], leg=False)
plot("raam_combo", ax=ax[2], leg=False)

# %% [markdown]
# Seems to be the case...

# %% [markdown]
# Now you can save all model results to a csv file in your local directory.

# %%
A.norm_access_df.to_csv("results.csv")

# %% [markdown]
# Gravity works too (here for doctors).  Not really appropriate in this case, since there is fixed supply.

# %%
plot("gravity_doc")
